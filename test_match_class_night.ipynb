# %%
##TODO
##who won game based on eom status and scores---

# %%
import requests

# %%
# with open('smart_themes_schedule_3.10.0.json') as f:
#     links = json.load(f)

# %%
header = {'accept':"appication/json"}
resp = requests.get("https://graph.xploree.in/cricket/auin01072021195484/commentary?limit=all", headers = header)
# resp = requests.get("https://graph.xploree.in/cricket/auin12172020195482/commentary?limit=all", headers = header)
# resp = requests.get("https://graph.xploree.in/cricket/nzpk01032021198122/commentary?limit=all", headers = header)
#auin12172020195482
# link_current = "https://cdn.graph.xploree.com/s/cricket-standings/?matchfile=auin01072021195484&utm_source=cricket-web&utm_medium=standings-banner&utm_content=auin12262020195483#/commentary"
# link_nz = "https://graph.xploree.in/cricket/nzpk01032021198122/commentary?limit=all"
# resp_current = requests.get(link_nz, headers = header)

# %%
# link2 = "https://cdn.graph.xploree.com/s/cricketvue?matchfile=auin12172020195484"
# response = requests.get(link2)

# %%
def generate_qna(question_str,answer_str):
	dict_ = dict()
	if not question_str.endswith('?'):
		question_str+= '?'
	dict_["question"] = question_str
	# if NO in answer_str:
	# 	dict_["answer"] = NOA
	# 	return dict_
	if answer_str == '\n':
		dict_["answer"] = NA
	if answer_str is None:
		dict_["answer"] = NA
	if answer_str == '' or answer_str == ' ':
		dict_["answer"] = NA
	else:
		dict_["answer"] = answer_str
	return dict_

# %%
data = resp.json()

# %%
def append_list(inp):
    return '\n'.join(inp)

# %%
match[team1].bowl1
# Out:
# {'Pat Cummins': {'overs': '21.4',
#   'runs_conceeded': 29,
#   'wickets': 4,
#   'wides': 0,
#   'no_ball': 0},
#  'Cameron Green': {'overs': '5.0',
#   'runs_conceeded': 11,
#   'wickets': 0,
#   'wides': 0,
#   'no_ball': 0},
#  'Mitchell Starc': {'overs': '19.1',
#   'runs_conceeded': 61,
#   'wickets': 1,
#   'wides': 0,
#   'no_ball': 1},
#  'Nathan Lyon': {'overs': '31.0',
#   'runs_conceeded': 87,
#   'wickets': 0,
#   'wides': 0,
#   'no_ball': 0},
#  'Josh Hazlewood': {'overs': '21.0',
#   'runs_conceeded': 43,
#   'wickets': 2,
#   'wides': 1,
#   'no_ball': 0},
#  'Marnus Labuschagne': {'overs': '3.0',
#   'runs_conceeded': 11,
#   'wickets': 0,
#   'wides': 0,
#   'no_ball': 0}}

# %%
match[team1]

# %%
# Out:
# [{'question': 'How many did Will Pucovski score?',
#   'answer': 'First innings\n62(110) 4s:4,6s:0,SR:56.36 \nSecond innings\n10(16) 4s:2,6s:0,SR:62.5 '},
#  {'question': 'How many did David Warner score?',
#   'answer': 'First innings\n5(8) 4s:0,6s:0,SR:62.5 \nSecond innings\n13(29) 4s:1,6s:0,SR:44.83 '}]

# %%
class Team:
    mom = ''
    def __init__(self, name):
        self.name = name
        self.bat1_score = 0
        self.bat1_wickets = 0
        self.bat2_score = 0
        self.bat2_wickets = 0
        self.bat_first = None
        self.bat1_status = False
        self.bat2_status = False
        self.bowl1_status = False
        self.bowl2_status = False
        self.bat1 = None
        self.bat2 = None
        self.toss = None
        self.bowl1 = None
        self.bowl2 = None
        self.bat_first = None
        self.bowl_first = None
        self.captain = None
        self.playing_eleven = None
        self.mom = None
        
    def get_scorecard(self,commentary):
        ##to do -- add maidens and no balls or wides
        ## run outs being added to bowler bowled fix needed
        batsman_scores = dict()
        bowler_stats = dict()
        wide = "WIDE"
        nobe = "NO BALL"
        for ball in commentary['list']:
            comm = ball["Commentary"]
            if ball['Isball']:
                bowler = ball["Bowler_Name"]
                batter = ball['Batsman_Name']
                score = int(ball['Batsman_Runs'])
                if bowler not in bowler_stats:
                    bowler_stats[bowler] ={'overs':0,'runs_conceeded':0, "wickets":0,
                                           "wides":0,"no_ball":0} 

                if batter not in batsman_scores:
                        batsman_scores[batter] = {'score':0,'balls':0,'4s':0,
                                                  '6s':0,'sr':0,'fow':'','wk_comm':''}
                if score == 4:
                    batsman_scores[batter]['4s']+=1
                if score == 6:
                    batsman_scores[batter]['6s'] +=1
                batsman_scores[batter]['score'] += int(score)
                batsman_scores[batter]['balls'] += 1
                bowler_stats[bowler]['runs_conceeded'] += int(ball["Bowler_Conceded_Runs"])
                f1 = wide in comm
                f2 = nobe in comm
                if f1:
                    bowler_stats[bowler]['wides']+=1
                elif f2:
                    bowler_stats[bowler]['no_ball']+=1
                else:
                    bowler_stats[bowler]['overs'] += 1
                if "Iswicket" in ball and ball['Iswicket']:
                    if ball['Dismissal_Type'] == 'run out':
                        continue
                    bowler_stats[bowler]['wickets'] += 1
                    batsman_scores[batter]['fow'] = ball['Over']
                    batsman_scores[batter]['wk_comm'] = comm

        for bowler in bowler_stats:
            overs_ = bowler_stats[bowler]['overs']//6
            decimal = bowler_stats[bowler]['overs'] % 6
            overs = str(overs_)+'.'+str(decimal)
            bowler_stats[bowler]['overs'] = overs
            ##fix extras
        for batsman in batsman_scores:
            sr = int(batsman_scores[batsman]['score'])/int(batsman_scores[batsman]['balls']) * (100)
            batsman_scores[batsman]['sr'] = round(sr,2)
        return batsman_scores, bowler_stats
    
    def update_batting(self,data):
        data_len = len(data)
        if self.bat_first:
            ##first_batting
            if data[-1]['innings'] == 1:
                batting_content = data[-1]
                ##aggreave data in 
                self.bat1 = self.get_scorecard(batting_content)[0]
                self.bat1_status = True
            if data_len > 2:
                if data[-3]['innings'] == 3:
                    batting_content = data[-3]
                    self.bat2 = self.get_scorecard(batting_content)[0]
                    self.bat2_status = True
        if not self.bat_first:
            if data[-2]['innings'] == 2:
                batting_content = data[-2]
                self.bat1 = self.get_scorecard(batting_content)[0]
                self.bat1_status = True
            if data_len >3:
                if data[-4]['innings'] == 4:
                    batting_content = data[-4]
                    self.bat2 = self.get_scorecard(batting_content)[0]
                    self.bat2_status = True
                    
    def update_score(self):
        #update bat1
        if self.bat1_status:
            for player in self.bat1:
                self.bat1_score+=self.bat1[player]['score']
                if self.bat1[player]['fow']:
                    self.bat1_wickets+=1
            self.bat1_score = str(self.bat1_score) + '/'+ str(self.bat1_wickets)
        if self.bat2_status:
            for player in self.bat1:
                self.bat2_score+=int(self.bat1[player]['score'])
                if self.bat1[player]['fow']:
                    self.bat2_wickets+=1
            self.bat2_score = str(self.bat2_score) + '/'+ str(self.bat2_wickets)
            
    def update_bowling(self,data):
        data_len=len(data)
        if self.bowl_first:
            if data[-1]['innings'] == 1:
                bowling_content = data[-1]
                self.bowl1 = self.get_scorecard(bowling_content)[1]
                self.bowl1_status = True
            if data_len > 2:
                if data[-3]['innings'] == 3:
                    bowling_content = data[-3]
                    self.bowl2 = self.get_scorecard(bowling_content)[1]
                    self.bowl2_status = True
        else:
            if data[-2]['innings'] == 2:
                bowling_content = data[-2]
                self.bowl1 = self.get_scorecard(bowling_content)[1]
                self.bowl1_status = True
            if data_len >3:
                if data[-4]['innings'] == 4:
                    bowling_content = data[-4]
                    self.bowl2 = self.get_scorecard(bowling_content)[1]
                    self.bowl2_status = True
    
    def get_bowling_summary(self,innings):
        if innings == 1 and self.bowl1_status:
            bowling = self.bowl1
            res = ["---First innigs---"]
        elif self.bowl2_status:
            bowling = self.bowl2
            res = ["---Second innigs---"]
        else:
            bowling = {}
        
        for player in bowling:
            s = "{} -- {}-{}-{}".format(player,bowling[player]['overs'],
                                bowling[player]['runs_conceeded'],bowling[player]['wickets'])
            res.append(s)
        return '\n'.join(res)
        
        
            
    def util_summary_batsman(self,summary,innings = 1):
        if innings == 1:
            ans = "---First Innings---\n"
        else:
            ans = "---Second Innings---\n"
        lis = []
        for idx,player in enumerate(summary['innings']):
            lis.append(player)
        lis = reversed(lis)
        for player in lis:
            player_ = summary['innings'][player]
            s = "{} {}({})".format(player,player_['score'],player_['balls'])
            ans+=s
            ans+='\n'
        ans+='\n'
        return ans

    def get_batting_summary(self,scores):
        """scores has innings key, result is input for util summary batsman"""
        result = dict()
        temp = dict()
        for key in scores:
            temp[key] = scores[key]
            result['innings'] = temp
        return result
    
    def get_bat_summ(self,innings):
        if innings == 1:
            tmp = self.get_batting_summary(self.bat1)
        else:
            tmp = self.get_batting_summary(self.bat2)
        return self.util_summary_batsman(tmp,innings)
    
    def get_x_comm(self, data,x):
        
        if self.bat_first:
            if self.bat1_status and self.bat2_status:
                idx_list = [len(data) -1, len(data) - 3]
                innings_list = [data[idx_list[0]],data[idx_list[1]]]
            else:
                idx_list = [len(data) -1]
                innings_list = [data[idx_list[0]]]
        else:
            if self.bat1_status and self.bat2_status:
                idx_list = [len(data) -2, len(data) - 4]
                innings_list = [data[idx_list[0]],data[idx_list[1]]]
            else:
                idx_list = [len(data)-2]
                innings_list = [data[idx_list[0]]]
            
        print(len(innings_list))
        comm = ["First Innings...."]
        flag = True
#         innings_list = [data[idx_list[0]],data[idx_list[1]]]
        for inning in innings_list:
            try:
                for ball in reversed(inning['list']):
                    if ball['Batsman_Runs'] == x:
                        comm.append(ball["Over"]+'--'+ball['Batsman_Name']+'--'+ball['Commentary'])
            except IndexError:
                print("index error")
            
            if flag and len(innings_list) > 1:
                comm.append("Second innings...")
                flag = False
        return comm
    
    def get_wickets_comm(self,data):
        if self.bat_first:
            if self.bat1_status and self.bat2_status:
                idx_list = [len(data) -1, len(data) - 3]
                innings_list = [data[idx_list[0]],data[idx_list[1]]]
            else:
                idx_list = [len(data) -1]
                innings_list = [data[idx_list[0]]]
        else:
            if self.bat1_status and self.bat2_status:
                idx_list = [len(data) -2, len(data) - 4]
                innings_list = [data[idx_list[0]],data[idx_list[1]]]
            else:
                idx_list = [len(data)-2]
                innings_list = [data[idx_list[0]]]
        flag = True
        comm = ["First Innings...."]
        for inning in innings_list:
            try:
                for ball in reversed(inning['list']):
                    if "Iswicket" in ball and ball['Iswicket']:
                        comm.append(ball['Over']+ " "+ball['Batsman_Name']+" "+ball["Commentary"])

            except IndexError:
                print("index error")
            if flag:
                comm.append("Second innings...")
                flag = False
        return comm
    def get_dropped(self,data):
        util = "DROPPED"
        if self.bat_first:
            if self.bat1_status and self.bat2_status:
                idx_list = [len(data) -1, len(data) - 3]
                innings_list = [data[idx_list[0]],data[idx_list[1]]]
            else:
                idx_list = [len(data) -1]
                innings_list = [data[idx_list[0]]]
        else:
            if self.bat1_status and self.bat2_status:
                idx_list = [len(data) -2, len(data) - 4]
                innings_list = [data[idx_list[0]],data[idx_list[1]]]
            else:
                idx_list = [len(data)-2]
                innings_list = [data[idx_list[0]]]
        comm = ["First Innings...."]
        flag = True
        for inning in innings_list:
            try:
                for ball in reversed(inning['list']):
                    if util in ball['Commentary']:
                        comm.append(ball["Over"]+ " "+ ball['Batsman_Name']+ ", "+ball['Commentary'])
            except IndexError:
                print("index error")
            if flag:
                comm.append("Second innings...")
                flag = False
        return comm

    def get_max_score_playerwise(self,innings):
        scores = {}
        result = dict()
        if innings == 1 and self.bat1_status:
            scores = self.bat1
        elif innings == 2 and self.bat2_status:
            scores = self.bat2
        new_dict = dict()
        for player in scores:
            new_dict[player] = scores[player]['score']
        sorted_x = sorted(new_dict.items(), key=lambda kv: kv[1],reverse = True)
        return sorted_x
    def get_scores_playerwise(self,innings):
        scores = {}
        result = dict()
        if innings == 1 and self.bat1_status:
            scores = self.bat1
        elif innings == 2 and self.bat2_status:
            scores = self.bat2
        new_dict = dict()
        for player in scores:
            s = "{}({}) 4s:{},6s:{},SR:{} ".format(scores[player]['score'],scores[player]['balls'],scores[player]['4s'],
                                                  scores[player]['6s'],scores[player]['sr'])
            new_dict[player] = s
#         sorted_x = sorted(new_dict.items(), key=lambda kv: kv[1],reverse = True)
        return new_dict
    
    def get_max_wickets_playerwise(self,innings):
        scores = {}
        result = dict()
        if innings == 1 and self.bowl1_status:
            scores = self.bowl1
        elif innings == 2 and self.bowl2_status:
            scores = self.bowl2
        new_dict = dict()
        for player in scores:
            new_dict[player] = scores[player]['wickets']
        print(new_dict)
        sorted_x = sorted(new_dict.items(), key=lambda kv: kv[1],reverse = True)
        return sorted_x
    def get_bowling_figures_playerwise(self,innings=1):
        if innings == 1:
            bowl = self.bowl1
        else:
            if self.bowl2_status:
                bowl = self.bowl2
        new_dict = dict()
        for player in bowl:
            player_ = bowl[player]
            ans = "{}-{}-{}".format(player_['overs'],player_['runs_conceeded'],player_['wickets'])
            new_dict[player] = ans
            
        return new_dict
    def get_fow_how_out(self,innings=1):
        if innings == 1 and self.bat1_status:
            bat = self.bat1
        else:
            if self.bat2_status:
                bat = self.bat2
        new_dict = dict()
        for player in bat:
            if player not in new_dict:
                new_dict[player] = [None,None]
            new_dict[player][0] = bat[player]['fow']
            new_dict[player][1] = bat[player]['wk_comm']
            
        return new_dict

# %%
match = dict()
team1,team2 = get_team_names(scorecard)
team1 = team1.lower().strip()
team2 = team2.lower().strip()
teams = [team1, team2]
playing_eleven = get_playing_eleven(data)
for team in teams:
    if team not in match:
        match[team] = Team(team)
        match[team].playing_eleven = playing_eleven[team]
toss_won = get_toss(scorecard).split(',')[0].lower().strip()
match[toss_won].toss = "won"
captains = get_captain(data, teams[0],teams[1])
for team in captains:
    match[team].captain = captains[team]
match[team1].bat_first = True
match[team1].bowl_first = False
match[team2].bowl_first = True
match[team2].bat_first = False
if match[team1].bat_first:
    team_bat_first = team1.title()
    team_bowl_first = team2.title()
else:
    team_bat_first = team2.title()
    team_bowl_first = team1.title()

match[team1].mom = get_mom(data) ##add eom stuff
match[team2].mom = get_mom(data)

# %%
match[team1].update_batting(data)
match[team2].update_batting(data)
match[team1].update_bowling(data)
match[team2].update_bowling(data)

# %%
match[team1].update_score()
match[team2].update_score()

# %%
match[team1].get_max_score_playerwise(1)
# Out:
# [('Steven Smith', 131),
#  ('Marnus Labuschagne', 91),
#  ('Will Pucovski', 62),
#  ('Mitchell Starc', 24),
#  ('Matthew Wade', 13),
#  ('David Warner', 5),
#  ('Josh Hazlewood', 1),
#  ('Tim Paine', 1),
#  ('Nathan Lyon', 0),
#  ('Pat Cummins', 0),
#  ('Cameron Green', 0)]

# %%
match[team1].get_fow_how_out(1)
# Out:
# {'Steven Smith': ['', ''],
#  'Josh Hazlewood': ['', ''],
#  'Nathan Lyon': ['102.4',
#   'OUT! LBW! That had to be plumb! Jadeja gets his fourth wicket of the game and even the review is not able to save Lyon. A full toss on off and middle, Lyon looks to play at this but he misses. It hits him on his boot. The players appeal and the umpire obliges, raising his finger. Lyon walks back but takes the review just to be sure. Ultra Edge shows not bat involved. Ball Tracker comes in and confirms that the on-field call is the right one. One last wicket remaining to take for the Indians.'],
#  'Mitchell Starc': ['101.5',
#   'OUT! CAUGHT! The rush of blood to Starc has made him lose his wicket! Shortish ball around middle and leg, Starc goes for the slog, but has no timing on that whatsoever. The ball balloons up in the air towards mid-wicket area, Gill\xa0from mid on runs to his left and completes an easy catch. A good cameo from Starc comes to an end. Australia 8 down now. How many more can they add now?'],
#  'Pat Cummins': ['94.4',
#   'OUT! TIMBER! Jadeja gets another one and the decision to bring on Jadeja is a masterclass by Rahane. Cummins goes back for a duck as well. Jadeja bowls this very full and around off, Cummins is late in getting his blade down in time to dig this one out. Cummins misses out. But the ball does not as it goes onto hit the off pole. A very good wicket for India and Australia lose their seventh wicket.'],
#  'Tim Paine': ['88.5',
#   'OUT! BOWLED! Knocked him over. Bumrah, you beauty! A fuller ball around off, comes back in slightly and Paine looks to have a push at this but plays it at the wrong line, there was not foot movement as well. The ball goes through the forward push of the Australian captain and goes onto disturb the timber behind. Bumrah has been lethal with the second new ball and has shown it again. Paine completely misjudged the line there and has to make his\xa0way back to the pavilion. Australia 6 down now.'],
#  'Cameron Green': ['84.5',
#   'OUT! LBW! Excellent bowling this by Bumrah. Green goes for a duck. After dishing out balls outside off, Bumrah\xa0bowls a length ball around off, makes it to jag back in. Green looks to defend but gets beaten by the pace and movement to get hit on the pads. The Indians appeal and the umpire obliges by raising his finger. Green has a word with Smith but decides against the review. A good decision as replays show that this would go onto hit the stumps. Green does not hang around for long.'],
#  'Matthew Wade': ['76.5',
#   'OUT! CAUGHT! Jadeja gets another wicket and sends another batter to the hut! There is always a sense of adventure about Wade and that adventure has made sure that he loses his wicket. He was looking good with his short stay out in the middle but that has been cut short by Jadeja and he is doing well to get wickets at regular intervals. Wade skips down the track as Jadeja goes for a flatter delivery around middle, Wade looks to tuck this one away to the leg side but he gets a leading edge and the ball balloons towards the mid on region, where Bumrah takes a good catch.'],
#  'Marnus Labuschagne': ['70.5',
#   "OUT! CAUGHT! Jadeja gets the breakthrough and Marnus, who was looking to get to his ton loses his wicket. The skipper takes a really good catch. Makes it to 91, but will not be able to cross the triple digit mark. Just the wicket that India needed and also at the right time. Jadeja goes for a short one and around the off pole, Labuschagne camps on his back foot and looks to punch\xa0this one away but the ball bounces a tad bit more and also spins away slightly, just enough to take\xa0the outside edge and go\xa0towards the first slip region, where Rahane gets low and makes no mistake. A sad end to Marnus' innings."],
#  'Will Pucovski': ['34.2',
#   'OUT! LBW! Saini has his first wicket! What a moment this is for the youngster! A debutant gets the other debutant and Saini is ecstatic. India needed to break this partnership and Navdeep has decided to take matters into his own hands. He bowls this on a length outside off, moves in after taking the deck, Pucovski takes too long to get his bat across and misses his flick away. Gets rapped on the pads. The players appeal and the umpire obliges raising his finger. Will is not going to review this one as he knows that this was plumb. A fine, fine stand comes to an end.'],
#  'David Warner': ['3.3',
#   "OUT! EDGED AND CAUGHT! India draw first blood! Warner's comeback does not end on a happy note for the left-hander and for the Aussies! Siraj, again, continues his good form in this Test series and he breaks this new opening stand. Siraj dishes this on a length around off, it moves away after pitching, Warner is drawn into the shot and he swings his blade at this. He can only induce an outside edge and the ball flies towards the slip cordon. Pujara is the man there at first slip and he is not going to drop this."]}

# %%
result_list = list()
result_list.append(generate_qna("Who is the captain of {}".format(team1.title()),
											match[team1].captain))

result_list.append(generate_qna("Who is the captain of {}".format(team2.title()),
											match[team2].captain))

result_list.append(generate_qna("Playing eleven of {}".format(team1.title())
								,match[team1].playing_eleven))

result_list.append(generate_qna("Playing eleven of {}".format(team2.title()),
								match[team2].playing_eleven))
result_list.append(generate_qna("Who won the toss",toss_won.title()))
result_list.append(generate_qna("who batted first", team_bat_first)) ##score card da.
result_list.append(generate_qna("who bowled first",team_bowl_first)) ## score card easy da.
#result_list.append(generate_qna("Who won the game",get_eom_status(scorecard,data))) ##write func to see result
# result_list.append(generate_qna("Who is the man of the match ",get_mom(data))) ##can be done from score card actually, not in sc,done
result_list.append(generate_qna("Batting summary of {}".format(team1.title()),
                            match[team1].get_bat_summ(1)+'\n'+match[team1].get_bat_summ(2)))
result_list.append(generate_qna("Batting summary of {}".format(team2.title()),
                            match[team2].get_bat_summ(1)+'\n'+match[team2].get_bat_summ(2)))
result_list.append(generate_qna("Bowling summary of {}".format(team1.title()),
                match[team1].get_bowling_summary(1)+'\n'+match[team1].get_bowling_summary(2)))
result_list.append(generate_qna("Bowling summary of {}".format(team2.title()),
                match[team2].get_bowling_summary(1)+'\n'+match[team2].get_bowling_summary(2)))
result_list.append(generate_qna("Fours commentary of {}".format(team1.title()),
									'\n'.join(match[team1].get_x_comm(data,'4'))))
result_list.append(generate_qna("Fours commentary of {}".format(team2.title()),
									'\n'.join(match[team2].get_x_comm(data,'4'))))
result_list.append(generate_qna("Sixes commentary of {}".format(team2.title()),
									'\n'.join(match[team2].get_x_comm(data,'6'))))
result_list.append(generate_qna("Sixes commentary of {}".format(team1.title()),
									'\n'.join(match[team1].get_x_comm(data,'6'))))
result_list.append(generate_qna("Wickets commentary of {}".format(team1),
									'\n'.join(match[team1].get_wickets_comm(data))))
result_list.append(generate_qna("Wickets commentary of {}".format(team2),
									'\n'.join(match[team2].get_wickets_comm(data))))
t1_i1 = match[team1].get_scores_playerwise(1)
t1_i2 = match[team1].get_scores_playerwise(2)
for player in t1_i1:
    ans = 'First innings\n'
    ans+=t1_i1[player]+'\n'
    if player in t1_i2:
        ans+='Second innings\n'
        ans+=t1_i2[player]
    else:
        if match[team1].bat2_status:
            ans+="Yet to bat/not batted"
        else:
            ans+="Innings yet to start\n"
    result_list.append(generate_qna("How many did {} score?".format(player),ans))
t2_i1 = match[team2].get_scores_playerwise(1)
t2_i2 = match[team2].get_scores_playerwise(2)
for player in t2_i1:
    ans = 'First innings\n'
    ans+=t2_i1[player]+'\n'
    if player in t2_i2:
        ans+='Second innings\n'
        ans+=t2_i2[player]
    else:
        if match[team2].bat2_status:
            ans+="Yet to bat/not batted"
        else:
            ans+="Innings yet to start\n"
    result_list.append(generate_qna("How many did {} score?".format(player),ans))

t1_b1 = match[team1].get_bowling_figures_playerwise(1)
t1_b2 = match[team1].get_bowling_figures_playerwise(2)
for player in t1_b1:
    ans = 'First innings\n'
    ans+=t1_b1[player]+'\n'
    if player in t1_b2:
        ans+='Second innings\n'
        ans+=t1_b2[player]
    else:
        if match[team1].bowl2_status:
            ans+="Havent bowled in second innings yet"
        else:
            ans+="Innings yet to start\n"
    result_list.append(generate_qna("Bowling figures of {}?".format(player),ans))

    
t2_b1 = match[team2].get_bowling_figures_playerwise(1)
t2_b2 = match[team2].get_bowling_figures_playerwise(2)
for player in t2_b1:
    ans = 'First innings\n'
    ans+=t2_b1[player]+'\n'
    if player in t2_b2:
        ans+='Second innings\n'
        ans+=t2_b2[player]
    else:
        if match[team2].bowl2_status:
            ans+="Havent bowled in second innings yet"
        else:
            ans+="second innings yet to start\n"
    result_list.append(generate_qna("Bowling figures of {}?".format(player),ans))

t1_i1 = match[team1].get_fow_how_out(1)
t1_i2 = match[team1].get_fow_how_out(2)

for player in t1_i1:
    ans1 = 'First Innings\n'
    ans2 = ans1
    if t1_i1[player][0]:
        ans1+=str(t1_i1[player][0])+'\n'
        ans2+=str(t1_i1[player][0])+' '+t1_i1[player][1]
    else:
        ans1+="Not out"
        ans2+="Not out"
    ans1+="Second Innings\n"    
    if player in t1_i2 and t1_i2[player][0]:
        ans1+=t1_i2[player][0]
        ans2+=str(t1_i2[player][0])+' '+t1_i2[player][1]
    else:
        if match[team1].bat2_status:
            ans1+="Yet to bat"
            ans2+="Yet to bat"
        else:
            ans1+="Second innings yet to start"
            ans2+="Second innings yet to start"
        
    result_list.append(generate_qna("Fall of wicket of {}".format(player),ans1))
    result_list.append(generate_qna("How did {} get out".format(player),ans2))

    
t2_i1 = match[team2].get_fow_how_out(1)
t2_i2 = match[team2].get_fow_how_out(2)

for player in t2_i1:
    ans1 = 'First Innings\n'
    ans2 = ans1
    if t2_i1[player][0]:
        ans1+=str(t2_i1[player][0])+'\n'
        ans2+=str(t2_i1[player][0])+' '+t2_i1[player][1]
    else:
        ans1+="Not out"
        ans2+="Not out"
    ans1+="Second Innings\n"
    ans2+="Second Innings\n"
    if player in t2_i2 and t2_i2[player][0]:
        ans1+=t2_i2[player][0]
        ans2+=str(t2_i2[player][0])+' '+t2_i2[player][1]
    else:
        if match[team2].bat2_status:
            ans1+="Has not come on yet"
        else:
            ans+="Second innings yet to start"
        
    result_list.append(generate_qna("Fall of wicket of {}".format(player),ans1))

ans="First Inning\n"
if match[team1].bat1_status:
    tmp =match[team1].get_max_score_playerwise(1)[0]
    ans+=tmp[0]+' '+str(tmp[1])
    ans+="\nSecond Innings"
    if match[team1].bat2_status:
        tmp=match[team1].get_max_score_playerwise(2)[0]
        ans+=tmp[0]+' '+str(tmp[1])
    else:
        ans+="Batting not started"
else:
    ans+="Batting not started"

result_list.append(generate_qna("Who scored most for {}".format(team1),ans))
ans="First Inning\n"
if match[team2].bat1_status:
    tmp =match[team2].get_max_score_playerwise(1)[0]
    ans+=tmp[0]+' '+str(tmp[1])
    ans+="\nSecond Innings"
    if match[team2].bat2_status:
        tmp=match[team2].get_max_score_playerwise(2)[0]
        ans+=tmp[0]+' '+str(tmp[1])
    else:
        ans+="Batting not started"
else:
    ans+="Batting not started"

result_list.append(generate_qna("Who scored most for {}".format(team2),ans))
result_list
# Out:
# 2
# 2
# 2
# 2
# [{'question': 'Who is the captain of Australia?',
#   'answer': 'Tim Paine (C/WK)'},
#  {'question': 'Who is the captain of India?', 'answer': 'Ajinkya Rahane (C)'},
#  {'question': 'Playing eleven of Australia?',
#   'answer': 'David Warner (IN PLACE OF JOE BURNS), Will Pucovski (IN PLACE OF TRAVIS HEAD), Marnus Labuschagne, Steven Smith, Matthew Wade, Cameron Green, Tim Paine (C/WK), Pat Cummins, Mitchell Starc, Nathan Lyon, Josh Hazlewood.'},
#  {'question': 'Playing eleven of India?',
#   'answer': 'Rohit Sharma (IN PLACE OF MAYANK AGARWAL), Shubman Gill, Cheteshwar Pujara, Ajinkya Rahane (C), Hanuma Vihari, Rishabh Pant (WK), Ravindra Jadeja, Ravichandran Ashwin, Jasprit Bumrah, Mohammed Siraj, Navdeep Saini (IN PLACE OF UMESH YADAV).'},
#  {'question': 'Who won the toss?', 'answer': 'Australia'},
#  {'question': 'who batted first?', 'answer': 'Australia'},
#  {'question': 'who bowled first?', 'answer': 'India'},
#  {'question': 'Batting summary of Australia?',
#   'answer': '---First Innings---\nDavid Warner 5(8)\nWill Pucovski 62(110)\nMarnus Labuschagne 91(196)\nMatthew Wade 13(16)\nCameron Green 0(22)\nTim Paine 1(10)\nPat Cummins 0(13)\nMitchell Starc 24(30)\nNathan Lyon 0(3)\nJosh Hazlewood 1(6)\nSteven Smith 131(226)\n\n\n---Second Innings---\nWill Pucovski 10(16)\nDavid Warner 13(29)\nMarnus Labuschagne 73(118)\nMatthew Wade 4(11)\nSteven Smith 81(167)\nTim Paine 39(52)\nCameron Green 84(132)\n\n'},
#  {'question': 'Batting summary of India?',
#   'answer': '---First Innings---\nRohit Sharma 26(77)\nShubman Gill 50(102)\nAjinkya Rahane 22(70)\nHanuma Vihari 4(38)\nRishabh Pant 36(67)\nCheteshwar Pujara 50(176)\nRavichandran Ashwin 10(15)\nNavdeep Saini 3(13)\nJasprit Bumrah 0(2)\nRavindra Jadeja 28(37)\nMohammed Siraj 6(10)\n\n\n---Second Innings---\nShubman Gill 31(64)\nRohit Sharma 52(98)\nAjinkya Rahane 4(18)\nRishabh Pant 64(80)\nCheteshwar Pujara 32(120)\n\n'},
#  {'question': 'Bowling summary of Australia?',
#   'answer': '---First innigs---\nPat Cummins -- 21.4-29-4\nCameron Green -- 5.0-11-0\nMitchell Starc -- 19.1-61-1\nNathan Lyon -- 31.0-87-0\nJosh Hazlewood -- 21.0-43-2\nMarnus Labuschagne -- 3.0-11-0\n---Second innigs---\nMitchell Starc -- 9.4-44-0\nNathan Lyon -- 21.0-63-1\nCameron Green -- 3.0-13-0\nMarnus Labuschagne -- 2.0-9-0\nJosh Hazlewood -- 13.0-20-1\nPat Cummins -- 14.1-38-1'},
#  {'question': 'Bowling summary of India?',
#   'answer': '---First innigs---\nJasprit Bumrah -- 25.4-66-2\nRavindra Jadeja -- 18.0-62-4\nNavdeep Saini -- 13.0-65-2\nMohammed Siraj -- 25.0-67-1\nRavichandran Ashwin -- 24.0-74-0\n---Second innigs---\nJasprit Bumrah -- 21.0-68-1\nMohammed Siraj -- 25.1-90-1\nNavdeep Saini -- 16.2-54-2\nRavichandran Ashwin -- 25.0-95-2'},
#  {'question': 'Fours commentary of Australia?',
better of him.\n67.2 Hanuma Vihari OUT! RUN OUT! Vihari is short. Stunning work from Hazlewood. A fuller ball just outside off, Vihari jumps out of his crease and pushes it wide of the man at mid off. He calls for the single straightaway and Pujara responds. Hazlewood from mid off dives to his right, stops the ball and hits the stumps at the non-striker's end, did that all in one motion. The Aussies celebrate. The third umpire has been called for and one replay is enough to send Vihari packing. His\xa0stay in the middle has been cut short, because of some stunning work from the big Josh.\n87.4 Rishabh Pant OUT! TAKEN! Pant's stay has been cut short. Hazlewood is the man who strikes. A fuller ball outside off, Pant without any feet movement goes for the drive but ends up getting an outside edge. The ball goes to Warner at first slip. It goes quickly to him but he reacts sharply and holds onto it. Great take from the southpaw. Not from the one with the bat though as it was way outside off and he could've had easily left it alone. A start thrown away again by Pant.\n88.2 Cheteshwar Pujara OUT! GONE! Huge wicket. Cummins is the man who has done it again. Big, big wicket. Excellent from Cummins. Good length and around off, it shoots off a touch after pitching. Pujara is glued in his crease as he pokes at it. The ball takes the gloves and goes behind. Paine is not going to miss out. A simple catch for him and he gobbles it. The battling knock from Pujara comes to an end and that leaves India in a massive trouble. They are still 143 behind.\n92.2 Ravindra Jadeja OUT! RUN OUT!\xa0Ashwin is short. Poor, poor running from him. A fullish ball outside off, Jadeja drives this to the left of fielder at mid off and takes off for the run. Ashwin is slow to react to it. Cummins from mid\xa0off\xa0throws the ball to Marnus Labuschagne at the striker's end and he whips off the bails before Ashwin can make his ground. Third umpire has been called and the replays show Ashwin short by some margin.\xa0Waste of a wicket this by Ashwin. Second run out of the innings this. India 7 down now.\n94.5 Navdeep Saini OUT! TAKEN! Starc gets the wicket with that short ball tactics. Smart from Paine to bring him back. Not that smart from Jadeja to expose Saini for entire six balls against Starc. Another short ball around off and middle, ...
#  {'question': 'How many did Steven Smith score?',
#   'answer': 'First innings\n131(226) 4s:16,6s:0,SR:57.96 \nSecond innings\n81(167) 4s:8,6s:1,SR:48.5 '},
#  {'question': 'How many did Josh Hazlewood score?',
#   'answer': 'First innings\n1(6) 4s:0,6s:0,SR:16.67 \nYet to bat/not batted'},
#  {'question': 'How many did Nathan Lyon score?',
#   'answer': 'First innings\n0(3) 4s:0,6s:0,SR:0.0 \nYet to bat/not batted'},
#  {'question': 'How many did Mitchell Starc score?',
#   'answer': 'First innings\n24(30) 4s:2,6s:1,SR:80.0 \nYet to bat/not batted'},
#  {'question': 'How many did Pat Cummins score?',
#   'answer': 'First innings\n0(13) 4s:0,6s:0,SR:0.0 \nYet to bat/not batted'},
#  {'question': 'How many did Tim Paine score?',
#   'answer': 'First innings\n1(10) 4s:0,6s:0,SR:10.0 \nSecond innings\n39(52) 4s:6,6s:0,SR:75.0 '},
#  {'question': 'How many did Cameron Green score?',
#   'answer': 'First innings\n0(22) 4s:0,6s:0,SR:0.0 \nSecond innings\n84(132) 4s:8,6s:4,SR:63.64 '},
#  {'question': 'How many did Matthew Wade score?',
#   'answer': 'First innings\n13(16) 4s:2,6s:0,SR:81.25 \nSecond innings\n4(11) 4s:1,6s:0,SR:36.36 '},
#  {'question': 'How many did Marnus Labuschagne score?',
#   'answer': 'First innings\n91(196) 4s:11,6s:0,SR:46.43 \nSecond innings\n73(118) 4s:9,6s:0,SR:61.86 '},
#  {'question': 'How many did Will Pucovski score?',
#   'answer': 'First innings\n62(110) 4s:4,6s:0,SR:56.36 \nSecond innings\n10(16) 4s:2,6s:0,SR:62.5 '},
#  {'question': 'How many did David Warner score?',
#   'answer': 'First innings\n5(8) 4s:0,6s:0,SR:62.5 \nSecond innings\n13(29) 4s:1,6s:0,SR:44.83 '},
#  {'question': 'How many did Mohammed Siraj score?',
#   'answer': 'First innings\n6(10) 4s:1,6s:0,SR:60.0 \nYet to bat/not batted'},
#  {'question': 'How many did Ravindra Jadeja score?',
#   'answer': 'First innings\n28(37) 4s:5,6s:0,SR:75.68 \nYet to bat/not batted'},
#  {'question': 'How many did Jasprit Bumrah score?',
#   'answer': 'First innings\n0(2) 4s:0,6s:0,SR:0.0 \nYet to bat/not batted'},
#  {'question': 'How many did Navdeep Saini score?',
#   'answer': 'First innings\n3(13) 4s:0,6s:0,SR:23.08 \nYet to bat/not batted'},
#  {'question': 'How many did Ravichandran Ashwin score?',
#   'answer': 'First innings\n10(15) 4s:2,6s:0,SR:66.67 \nYet to bat/not batted'},
#  {'question': 'How many did Cheteshwar Pujara score?',
#   'answer': 'First innings\n50(176) 4s:5,6s:0,SR:28.41 \nSecond innings\n32(120) 4s:3,6s:0,SR:26.67 '},
#  {'question': 'How many did Rishabh Pant score?',
#   'answer': 'First innings\n36(67) 4s:4,6s:0,SR:53.73 \nSecond innings\n64(80) 4s:6,6s:3,SR:80.0 '},
#  {'question': 'How many did Hanuma Vihari score?',
#   'answer': 'First innings\n4(38) 4s:0,6s:0,SR:10.53 \nYet to bat/not batted'},
#  {'question': 'How many did Ajinkya Rahane score?',
#   'answer': 'First innings\n22(70) 4s:1,6s:1,SR:31.43 \nSecond innings\n4(18) 4s:0,6s:0,SR:22.22 '},
#  {'question': 'How many did Shubman Gill score?',
#   'answer': 'First innings\n50(102) 4s:8,6s:0,SR:49.02 \nSecond innings\n31(64) 4s:4,6s:0,SR:48.44 '},
#  {'question': 'How many did Rohit Sharma score?',
#   'answer': 'First innings\n26(77) 4s:3,6s:1,SR:33.77 \nSecond innings\n52(98) 4s:5,6s:1,SR:53.06 '},
#  {'question': 'Bowling figures of Pat Cummins?',
#   'answer': 'First innings\n21.4-29-4\nSecond innings\n14.1-38-1'},
#  {'question': 'Bowling figures of Cameron Green?',
#   'answer': 'First innings\n5.0-11-0\nSecond innings\n3.0-13-0'},
#  {'question': 'Bowling figures of Mitchell Starc?',
#   'answer': 'First innings\n19.1-61-1\nSecond innings\n9.4-44-0'},
#  {'question': 'Bowling figures of Nathan Lyon?',
#   'answer': 'First innings\n31.0-87-0\nSecond innings\n21.0-63-1'},
#  {'question': 'Bowling figures of Josh Hazlewood?',
#   'answer': 'First innings\n21.0-43-2\nSecond innings\n13.0-20-1'},
#  {'question': 'Bowling figures of Marnus Labuschagne?',
#   'answer': 'First innings\n3.0-11-0\nSecond innings\n2.0-9-0'},
#  {'question': 'Bowling figures of Jasprit Bumrah?',
#   'answer': 'First innings\n25.4-66-2\nSecond innings\n21.0-68-1'},
#  {'question': 'Bowling figures of Ravindra Jadeja?',
#   'answer': 'First innings\n18.0-62-4\nHavent bowled in second innings yet'},
#  {'question': 'Bowling figures of Navdeep Saini?',
#   'answer': 'First innings\n13.0-65-2\nSecond innings\n16.2-54-2'},
#  {'question': 'Bowling figures of Mohammed Siraj?',
#   'answer': 'First innings\n25.0-67-1\nSecond innings\n25.1-90-1'},
#  {'question': 'Bowling figures of Ravichandran Ashwin?',
#   'answer': 'First innings\n24.0-74-0\nSecond innings\n25.0-95-2'},
#  {'question': 'Fall of wicket of Steven Smith?',
#   'answer': 'First Innings\nNot outSecond Innings\n67.4'},
#  {'question': 'How did Steven Smith get out?',
#   'answer': "First Innings\nNot out67.4 OUT! LBW! THREE REDS! Just what India wanted and the technology comes to their assistance there. Ashwin bowls a nice tossed up ball around off,\xa0 gets it to turn a bit towards Smith. Steven there comes on the front foot to defend but the ball spins past him and raps him flush on the pads. Ashwin appeals and there is a shake of head from the umpire. Rahane signals 'T' immediately. Replays roll in. Firstly it is a fair delivery as Hot Spot does not show bat involved. Snicko comes in and confirms the same. Time for Hawk Eye now. Pitching in line, Impact in Line and Wickets Hitting. Three reds and Smith has to take the long walk back. India would be relieved to see the back of Steven Smith and now would hope to wrap the Australian innings quickly to set up the chase here."},
#  {'question': 'Fall of wicket of Josh Hazlewood?',
#   'answer': 'First Innings\nNot outSecond Innings\nYet to bat'},
#  {'question': 'How did Josh Hazlewood get out?',
#   'answer': 'First Innings\nNot outYet to bat'},
#  {'question': 'Fall of wicket of Nathan Lyon?',
#   'answer': 'First Innings\n102.4\nSecond Innings\nYet to bat'},
#  {'question': 'How did Nathan Lyon get out?',
#   'answer': 'First Innings\n102.4 OUT! LBW! That had to be plumb! Jadeja gets his fourth wicket of the game and even the review is not able to save Lyon. A full toss on off and middle, Lyon looks to play at this but he misses. It hits him on his boot. The players appeal and the umpire obliges, raising his finger. Lyon walks back but takes the review just to be sure. Ultra Edge shows not bat involved. Ball Tracker comes in and confirms that the on-field call is the right one. One last wicket remaining to take for the Indians.Yet to bat'},
#  {'question': 'Fall of wicket of Mitchell Starc?',
#   'answer': 'First Innings\n101.5\nSecond Innings\nYet to bat'},
#  {'question': 'How did Mitchell Starc get out?',
#   'answer': 'First Innings\n101.5 OUT! CAUGHT! The rush of blood to Starc has made him lose his wicket! Shortish ball around middle and leg, Starc goes for the slog, but has no timing on that whatsoever. The ball balloons up in the air towards mid-wicket area, Gill\xa0from mid on runs to his left and completes an easy catch. A good cameo from Starc comes to an end. Australia 8 down now. How many more can they add now?Yet to bat'},
#  {'question': 'Fall of wicket of Pat Cummins?',
#   'answer': 'First Innings\n94.4\nSecond Innings\nYet to bat'},
#  {'question': 'How did Pat Cummins get out?',
#   'answer': "First Innings\n70.5 OUT! CAUGHT! Jadeja gets the breakthrough and Marnus, who was looking to get to his ton loses his wicket. The skipper takes a really good catch. Makes it to 91, but will not be able to cross the triple digit mark. Just the wicket that India needed and also at the right time. Jadeja goes for a short one and around the off pole, Labuschagne camps on his back foot and looks to punch\xa0this one away but the ball bounces a tad bit more and also spins away slightly, just enough to take\xa0the outside edge and go\xa0towards the first slip region, where Rahane gets low and makes no mistake. A sad end to Marnus' innings.46.1 OUT! CAUGHT! Taken down the leg side! The substitute keeper Saha takes a sensational take! A crucial stand is broken. Bowls a fast one on a length on leg, Labuschagne as he does so well looks to help it on its way to the leg side but the extra bit of bounce there means the ball goes off the edge and towards the left of the keeper. Saha, the substitute keeper dives full length to that side to pouch it. Can India capitalise on this opening?"},
#  {'question': 'Fall of wicket of Will Pucovski?',
#   'answer': 'First Innings\n34.2\nSecond Innings\n5.5'},
#  {'question': 'How did Will Pucovski get out?',
#   'answer': 'First Innings\n34.2 OUT! LBW! Saini has his first wicket! What a moment this is for the youngster! A debutant gets the other debutant and Saini is ecstatic. India needed to break this partnership and Navdeep has decided to take matters into his own hands. He bowls this on a length outside off, moves in after taking the deck, Pucovski takes too long to get his bat across and misses his flick away. Gets rapped on the pads. The players appeal and the umpire obliges raising his finger. Will is not going to review this one as he knows that this was plumb. A fine, fine stand comes to an end.5.5 OUT! CAUGHT! This is a beautiful delivery\xa0by Siraj. A length ball around off, shapes away affter pitching. Pucovski looks to defend but is surprised by the movement. The ball takes the outside edge and goes towards Saha, the substitute keeper, who pouches it nicely\xa0by diving to his right. Siraj is rewarded for bowling some good lines here. Australia lose their 1st wicket.'},
#  {'question': 'Fall of wicket of David Warner?',
#   'answer': 'First Innings\n3.3\nSecond Innings\n9.2'},
#  {'question': 'How did David Warner get out?',
#   'answer': "First Innings\n3.3 OUT! EDGED AND CAUGHT! India draw first blood! Warner's comeback does not end on a happy note for the left-hander and for the Aussies! Siraj, again, continues his good form in this Test series and he breaks this new opening stand. Siraj dishes this on a length around off, it moves away after pitching, Warner is drawn into the shot and he swings his blade at this. He can only induce an outside edge and the ball flies towards the slip cordon. Pujara is the man there at first slip and he is not going to drop this.9.2 OUT! LBW! Umpire's call on hitting the wickets. Ashwin has his man early in his spell. Both the Aussie openers dismissed inside the first 10 overs. A tossed up ball around off and middle, Warner gets down and looks to play the sweep but misses to get hit on the pads. Looks pretty good as the Indians appeal. The umpire takes his time and then raises the finger. Warner signals the 'T' after having a word with his partner at the other end. Hot Spot and Snicko detetcs nothing. Ball Tracker shows that the ball would clip the stumps. So, Warner has to go."},
#  {'question': 'Fall of wicket of Mohammed Siraj?',
#   'answer': 'First Innings\n100.4\nSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Ravindra Jadeja?',
#   'answer': 'First Innings\nNot outSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Jasprit Bumrah?',
#   'answer': 'First Innings\nNot outSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Navdeep Saini?',
#   'answer': 'First Innings\n94.5\nSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Ravichandran Ashwin?',
#   'answer': 'First Innings\nNot outSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Cheteshwar Pujara?',
#   'answer': 'First Innings\n88.2\nSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Rishabh Pant?',
#   'answer': 'First Innings\n87.4\nSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Hanuma Vihari?',
#   'answer': 'First Innings\nNot outSecond Innings\nHas not come on yet'},
#  {'question': 'Fall of wicket of Ajinkya Rahane?',
#   'answer': 'First Innings\n54.4\nSecond Innings\n35.4'},
#  {'question': 'Fall of wicket of Shubman Gill?',
#   'answer': 'First Innings\n32.1\nSecond Innings\n22.1'},
#  {'question': 'Fall of wicket of Rohit Sharma?',
#   'answer': 'First Innings\n26.6\nSecond Innings\n30.2'},
#  {'question': 'Who scored most for australia?',
#   'answer': 'First Inning\nSteven Smith 131\nSecond InningsCameron Green 84'},
#  {'question': 'Who scored most for india?',
#   'answer': 'First Inning\nCheteshwar Pujara 50\nSecond InningsRishabh Pant 64'}]

# %%
##boundaries -- direct to batsman scores
# how out -- done
##fow -- done
##max_runs,max_wickets -- to do, do now
##match_status -- to do
##mom -- to do

# %%
match[team1].bat1
# Out:
# {'Steven Smith': {'score': 131,
#   'balls': 226,
#   '4s': 16,
#   '6s': 0,
#   'sr': 57.96,
#   'fow': '',
#   'wk_comm': ''},
#  'Josh Hazlewood': {'score': 1,
#   'balls': 6,
#   '4s': 0,
#   '6s': 0,
#   'sr': 16.67,
#   'fow': '',
#   'wk_comm': ''},
#  'Nathan Lyon': {'score': 0,
#   'balls': 3,
#   '4s': 0,
#   '6s': 0,
#   'sr': 0.0,
#   'fow': '102.4',
#   'wk_comm': 'OUT! LBW! That had to be plumb! Jadeja gets his fourth wicket of the game and even the review is not able to save Lyon. A full toss on off and middle, Lyon looks to play at this but he misses. It hits him on his boot. The players appeal and the umpire obliges, raising his finger. Lyon walks back but takes the review just to be sure. Ultra Edge shows not bat involved. Ball Tracker comes in and confirms that the on-field call is the right one. One last wicket remaining to take for the Indians.'},
#  'Mitchell Starc': {'score': 24,
#   'balls': 30,
#   '4s': 2,
#   '6s': 1,
#   'sr': 80.0,
#   'fow': '101.5',
#   'wk_comm': 'OUT! CAUGHT! The rush of blood to Starc has made him lose his wicket! Shortish ball around middle and leg, Starc goes for the slog, but has no timing on that whatsoever. The ball balloons up in the air towards mid-wicket area, Gill\xa0from mid on runs to his left and completes an easy catch. A good cameo from Starc comes to an end. Australia 8 down now. How many more can they add now?'},
#  'Pat Cummins': {'score': 0,
#   'balls': 13,
#   '4s': 0,
#   '6s': 0,
#   'sr': 0.0,
#   'fow': '94.4',
#   'wk_comm': 'OUT! TIMBER! Jadeja gets another one and the decision to bring on Jadeja is a masterclass by Rahane. Cummins goes back for a duck as well. Jadeja bowls this very full and around off, Cummins is late in getting his blade down in time to dig this one out. Cummins misses out. But the ball does not as it goes onto hit the off pole. A very good wicket for India and Australia lose their seventh wicket.'},
#  'Tim Paine': {'score': 1,
#   'balls': 10,
#   '4s': 0,
#   '6s': 0,
#   'sr': 10.0,
#   'fow': '88.5',
#   'wk_comm': 'OUT! BOWLED! Knocked him over. Bumrah, you beauty! A fuller ball around off, comes back in slightly and Paine looks to have a push at this but plays it at the wrong line, there was not foot movement as well. The ball goes through the forward push of the Australian captain and goes onto disturb the timber behind. Bumrah has been lethal with the second new ball and has shown it again. Paine completely misjudged the line there and has to make his\xa0way back to the pavilion. Australia 6 down now.'},
#  'Cameron Green': {'score': 0,
#   'balls': 22,
#   '4s': 0,
#   '6s': 0,
#   'sr': 0.0,
#   'fow': '84.5',
#   'wk_comm': 'OUT! LBW! Excellent bowling this by Bumrah. Green goes for a duck. After dishing out balls outside off, Bumrah\xa0bowls a length ball around off, makes it to jag back in. Green looks to defend but gets beaten by the pace and movement to get hit on the pads. The Indians appeal and the umpire obliges by raising his finger. Green has a word with Smith but decides against the review. A good decision as replays show that this would go onto hit the stumps. Green does not hang around for long.'},
#  'Matthew Wade': {'score': 13,
#   'balls': 16,
#   '4s': 2,
#   '6s': 0,
#   'sr': 81.25,
#   'fow': '76.5',
#   'wk_comm': 'OUT! CAUGHT! Jadeja gets another wicket and sends another batter to the hut! There is always a sense of adventure about Wade and that adventure has made sure that he loses his wicket. He was looking good with his short stay out in the middle but that has been cut short by Jadeja and he is doing well to get wickets at regular intervals. Wade skips down the track as Jadeja goes for a flatter delivery around middle, Wade looks to tuck this one away to the leg side but he gets a leading edge and the ball balloons towards the mid on region, where Bumrah takes a good catch.'},
#  'Marnus Labuschagne': {'score': 91,
#   'balls': 196,
#   '4s': 11,
#   '6s': 0,
#   'sr': 46.43,
#   'fow': '70.5',
#   'wk_comm': "OUT! CAUGHT! Jadeja gets the breakthrough and Marnus, who was looking to get to his ton loses his wicket. The skipper takes a really good catch. Makes it to 91, but will not be able to cross the triple digit mark. Just the wicket that India needed and also at the right time. Jadeja goes for a short one and around the off pole, Labuschagne camps on his back foot and looks to punch\xa0this one away but the ball bounces a tad bit more and also spins away slightly, just enough to take\xa0the outside edge and go\xa0towards the first slip region, where Rahane gets low and makes no mistake. A sad end to Marnus' innings."},
#  'Will Pucovski': {'score': 62,
#   'balls': 110,
#   '4s': 4,
#   '6s': 0,
#   'sr': 56.36,
#   'fow': '34.2',
#   'wk_comm': 'OUT! LBW! Saini has his first wicket! What a moment this is for the youngster! A debutant gets the other debutant and Saini is ecstatic. India needed to break this partnership and Navdeep has decided to take matters into his own hands. He bowls this on a length outside off, moves in after taking the deck, Pucovski takes too long to get his bat across and misses his flick away. Gets rapped on the pads. The players appeal and the umpire obliges raising his finger. Will is not going to review this one as he knows that this was plumb. A fine, fine stand comes to an end.'},
#  'David Warner': {'score': 5,
#   'balls': 8,
#   '4s': 0,
#   '6s': 0,
#   'sr': 62.5,
#   'fow': '3.3',
#   'wk_comm': "OUT! EDGED AND CAUGHT! India draw first blood! Warner's comeback does not end on a happy note for the left-hander and for the Aussies! Siraj, again, continues his good form in this Test series and he breaks this new opening stand. Siraj dishes this on a length around off, it moves away after pitching, Warner is drawn into the shot and he swings his blade at this. He can only induce an outside edge and the ball flies towards the slip cordon. Pujara is the man there at first slip and he is not going to drop this."}}

# %%
##result_list.append(generate_qna("Who won the game",get_eom_status(scorecard,data))) ##write func to see result
#need t

    
for qna in result_list:
    print(qna['question'])
    print("**************")
    print(qna["answer"])
    print('\n')
# Out:
# Who is the captain of Australia?
# **************
# Tim Paine (C/WK)
#
#
# Who is the captain of India?
# **************
# Ajinkya Rahane (C)
#
#
# Playing eleven of Australia?
# **************
# David Warner (IN PLACE OF JOE BURNS), Will Pucovski (IN PLACE OF TRAVIS HEAD), Marnus Labuschagne, Steven Smith, Matthew Wade, Cameron Green, Tim Paine (C/WK), Pat Cummins, Mitchell Starc, Nathan Lyon, Josh Hazlewood.
#
#
# Playing eleven of India?
# **************
# Rohit Sharma (IN PLACE OF MAYANK AGARWAL), Shubman Gill, Cheteshwar Pujara, Ajinkya Rahane (C), Hanuma Vihari, Rishabh Pant (WK), Ravindra Jadeja, Ravichandran Ashwin, Jasprit Bumrah, Mohammed Siraj, Navdeep Saini (IN PLACE OF UMESH YADAV).
#
#
# Who won the toss?
# **************
# Australia
#
#
# who batted first?
# **************
# Australia
#
#
# who bowled first?
# **************
# India
#
#
# Batting summary of Australia?
# **************
# ---First Innings---
# David Warner 5(8)
# Will Pucovski 62(110)
# Marnus Labuschagne 91(196)
# Matthew Wade 13(16)
# Cameron Green 0(22)
# Tim Paine 1(10)
# Pat Cummins 0(13)
# Mitchell Starc 24(30)
# Nathan Lyon 0(3)
# Josh Hazlewood 1(6)
# Steven Smith 131(226)
#
#
# ---Second Innings---
# Will Pucovski 10(16)
# David Warner 13(29)
# Marnus Labuschagne 73(118)
# Matthew Wade 4(11)
# Steven Smith 81(167)
# Tim Paine 39(52)
# Cameron Green 84(132)
#
#
#
#
# Batting summary of India?
# **************
# ---First Innings---
# Rohit Sharma 26(77)
# Shubman Gill 50(102)
# Ajinkya Rahane 22(70)
# Hanuma Vihari 4(38)
# Rishabh Pant 36(67)
# Cheteshwar Pujara 50(176)
# Ravichandran Ashwin 10(15)
# Navdeep Saini 3(13)
# Jasprit Bumrah 0(2)
# Ravindra Jadeja 28(37)
# Mohammed Siraj 6(10)
#
#
# ---Second Innings---
# Shubman Gill 31(64)
# Rohit Sharma 52(98)
# Ajinkya Rahane 4(18)
# Rishabh Pant 64(80)
# Cheteshwar Pujara 32(120)
#
#
#
#
# Bowling summary of Australia?
# **************
# ---First innigs---
# Pat Cummins -- 21.4-29-4
# Cameron Green -- 5.0-11-0
# Mitchell Starc -- 19.1-61-1
# Nathan Lyon -- 31.0-87-0
# Josh Hazlewood -- 21.0-43-2
# Marnus Labuschagne -- 3.0-11-0
# ---Second innigs---
# Mitchell Starc -- 9.4-44-0
# Nathan Lyon -- 21.0-63-1
# Cameron Green -- 3.0-13-0
# Marnus Labuschagne -- 2.0-9-0
# Josh Hazlewood -- 13.0-20-1
# Pat Cummins -- 14.1-38-1
#
#
# Bowling summary of India?
# **************
# ---First innigs---
# Jasprit Bumrah -- 25.4-66-2
# 74.3--Rishabh Pant--FOUR! CUTS AND CUTS HARD! A short ball outside off, Pant hops and cuts this fiercely towards third man for a boundary. Pant looking good here.
# 81.4--Rishabh Pant--FOUR! Squirts it away! Shortish and just outside off, Pant goes on the back foot and looks to cut. Ends up chopping it through gully for a boundary.
# 86.3--Cheteshwar Pujara--FOUR! Nicely done from Pujara. A fuller ball just outside off, he comes on the front foot and then opens the bat face. It goes between second slip and gully. It races away to the fence. He moves to 49. The boundary brings up 50-run stand between the two. A valuable stand.
# 89.4--Ravichandran Ashwin--FOUR! Ashwin is off the mark in style. A fuller ball outside off, Ashwin leans into the stroke and drives it through the covers. Fine shot to bring 200 up.
# 91.2--Ravichandran Ashwin--FOUR! Nicely played. a tossed up ball outside off, Ashwin comes down and drills this one down the ground past mid off for his second boundary.
# 95.1--Ravindra Jadeja--FOUR! Cut away! Short and just outside off, Jadeja cuts it through backward point and it races away to the fence.
# 96.5--Ravindra Jadeja--FOUR! Useful boundary. Full and around off, Jadeja nails it through mid on for a boundary. Starc has overstepped too.
# 96.5--Ravindra Jadeja--EDGED AND FOUR! Welcome runs! Fuller and outside off, Jadeja goes for a big slog again. The ball though takes the bottom edge and goes behind. Paine dives to his right and tries to stop but the ball evades him and goes to the fence.
# 97.5--Mohammed Siraj--FOUR! Cut away! Short and wide outside off, Siraj cuts it through backward point and finds the fence.
# 98.1--Ravindra Jadeja--FOUR! Enough of ducking says Jadeja. A short ball on middle, Jadeja goes for the pull, gets a top edge which runs away towards the boundary at fine leg area. It bounces well ahead of the ropes but nonetheless a boundary for Jadeja.
# 99.6--Ravindra Jadeja--FOUR! Slammed away. Shortish around off, Jadeja pulls this one behind square and finds the gap at deep square leg area. Gets a boundary on the last ball of the over, which means Siraj will be on strike the next over.
# Second innings...
# 4.1--Rohit Sharma--FOUR! Nicely played. A fuller ball outside off, Rohit drives this one past the fielder at gully towards the fence at third man. First boundary for Rohit.
# 6.5--Shubman Gill--FOUR! Nicely punched! Back of a length ball on off, Gill punches it through covers and fetches a boundary.
# 12.4--Shubman Gill--FOUR! Helped on! Full and angled on the pads, Gill flicks it through fine leg for a boundary.
# 12.6--Shubman Gill--FOUR! EDGY! Back of a length around off, Gill is stranded on the back foot as he gets an outside edge on his push. The ball runs through gully and into the fence at third man for a single.
# 16.5--Rohit Sharma--FOUR! SHOT! Fuller ball outside off, Rohit drives this one gloriously through the cover point region for a boundary. Class shot from Rohit here.
# 18.6--Shubman Gill--FOUR! Smacked down the ground. A shortish ball around off, Gill pulls this one down the ground wide of the fielder at mid on and collects a boundary. Moves onto 30 now.
# 19.1--Rohit Sharma--FOUR! Elegantly played. A fuller ball outside off, Rohit leans on to this one and drives this one thorugh the covers for a boundary.  50-run stand is up between these two.
# 19.3--Rohit Sharma--FOUR! SHOT OF THE INNINGS. A fullish ball outside off, Rohit leans and drives this one past the cover-point area for the second boundary of the over. That had CLASS written all over it.
# 25.3--Cheteshwar Pujara--FOUR! This time manages to get it to the fence does Pujara. Tossed up on off, Puajra drives it through covers and fetches a boundary.
# 92.2 Ravindra Jadeja OUT! RUN OUT! Ashwin is short. Poor, poor running from him. A fullish ball outside off, Jadeja drives this to the left of fielder at mid off and takes off for the run. Ashwin is slow to react to it. Cummins from mid off throws the ball to Marnus Labuschagne at the striker's end and he whips off the bails before Ashwin can make his ground. Third umpire has been called and the replays show Ashwin short by some margin. Waste of a wicket this by Ashwin. Second run out of the innings this. India 7 down now.
# 94.5 Navdeep Saini OUT! TAKEN! Starc gets the wicket with that short ball tactics. Smart from Paine to bring him back. Not that smart from Jadeja to expose Saini for entire six balls against Starc. Another short ball around off and middle, Saini is hopping to fend it away. This time the Aussies brought a man at silly point. The ball hits the upper part of the bat and it goes to Wade. Wade is not dropping this. Perfectly planned wicket.
# 96.3 Ravindra Jadeja OUT! RUN OUT! 3rd run out of the innings. Jadeja clips this fuller ball towards deep square leg and immediately calls for two. The fielder from short leg, Labuschagne chases the ball down and scores a direct hit at the non-striker's end. Third umpire has been called for and replays show that Bumrah is well short there and has to make his way back to the pavilion. Australia have been excellent in the field especially with the direct hits. India 9 down now.
# 100.4 Mohammed Siraj OUT! CAUGHT BEHIND! There is a spike as the ball gets closer to the bat, as shown by the Snicko. After banging three short, Cummins bowls a length ball just outside off, Siraj pokes at it without moving his feet. He ends up nicking it behind and the Aussies celebrate.The finger goes up but Siraj signals the 'T'. Replays roll in and they show a big spike on the Snicko. So, the onfield call will stay. India are bowled out for 244.
# Second innings...
# 22.1 Shubman Gill OUT! Caught! Australia get the breakthrough. Length and around off, Gill looks to play this one off the back foot as he stays grounded inside the crease. The ball though shapes away a little as it takes the outside edge. There is an appeal and the umpire raises his finger. Gill though takes it upstairs as the replays roll in. Hot Spot comes in and it detects a spot when the ball is near the bat. Gill wastes a review as he walks back to the hut. Once again India fail to continue after a good opening stand.
# 30.2 Rohit Sharma OUT! CAUGHT! Sharma departs against the run of play! Rohit looks disappointed there. He got out to a shot which he loves playing and has fetched runs for him but this time it is not to be. Cummins nicely sets up the wicket by bowling it on a length on the first ball and now he bowls a short one and invites Rohit to go for the pull. Sharma obliges but fails to get the distance this time as the fielder at fine leg, Mitchell Starc takes it with ease. India once again lose both their openers after a good start.
# 35.4 Ajinkya Rahane OUT! CAUGHT! What a catch! That is nothing than a reaction catch. Australia needed it and Lyon delivers it. India disappointed after a failure from their skipper. Tossed up on off, Rahane prods forward to defend but does not play for the extra spin there as the ball takes the inside edge and goes towards short leg who takes a good low catch. Matthew Wade it is there under the helmet.
#
#
# How many did Steven Smith score?
# **************
# First innings
# 131(226) 4s:16,6s:0,SR:57.96
# Second innings
# 81(167) 4s:8,6s:1,SR:48.5
#
#
# How many did Josh Hazlewood score?
# **************
# First innings
# 1(6) 4s:0,6s:0,SR:16.67
# Yet to bat/not batted
#
#
# How many did Nathan Lyon score?
# **************
# First innings
# 0(3) 4s:0,6s:0,SR:0.0
# Yet to bat/not batted
#
#
# How many did Mitchell Starc score?
# **************
# First innings
# 24(30) 4s:2,6s:1,SR:80.0
# Yet to bat/not batted
#
#
# How many did Pat Cummins score?
# **************
# First innings
# 0(13) 4s:0,6s:0,SR:0.0
# Yet to bat/not batted
#
#
# How many did Tim Paine score?
# **************
# First innings
# 1(10) 4s:0,6s:0,SR:10.0
# Second innings
# 39(52) 4s:6,6s:0,SR:75.0
#
#
# How many did Cameron Green score?
# **************
# First innings
# 0(22) 4s:0,6s:0,SR:0.0
# Second innings
# 84(132) 4s:8,6s:4,SR:63.64
#
#
# How many did Matthew Wade score?
# **************
# First innings
# 13(16) 4s:2,6s:0,SR:81.25
# Second innings
# 4(11) 4s:1,6s:0,SR:36.36
#
#
# How many did Marnus Labuschagne score?
# **************
# First innings
# 91(196) 4s:11,6s:0,SR:46.43
# Second innings
# 73(118) 4s:9,6s:0,SR:61.86
#
#
# How many did Will Pucovski score?
# **************
# First innings
# 62(110) 4s:4,6s:0,SR:56.36
# Second innings
# 10(16) 4s:2,6s:0,SR:62.5
#
#
# How many did David Warner score?
# **************
# First innings
# 5(8) 4s:0,6s:0,SR:62.5
# Second innings
# 13(29) 4s:1,6s:0,SR:44.83
#
#
# How many did Mohammed Siraj score?
# **************
# First innings
# 6(10) 4s:1,6s:0,SR:60.0
# Yet to bat/not batted
#
#
# How many did Ravindra Jadeja score?
# **************
# First innings
# 28(37) 4s:5,6s:0,SR:75.68
# Yet to bat/not batted
#
#
# How many did Jasprit Bumrah score?
# **************
# First innings
# 0(2) 4s:0,6s:0,SR:0.0
# Yet to bat/not batted
#
#
# How many did Navdeep Saini score?
# **************
# First innings
# 3(13) 4s:0,6s:0,SR:23.08
# Yet to bat/not batted
#
#
# How many did Ravichandran Ashwin score?
# **************
# First innings
# 10(15) 4s:2,6s:0,SR:66.67
# Yet to bat/not batted
#
#
# How many did Cheteshwar Pujara score?
# **************
# First innings
# 50(176) 4s:5,6s:0,SR:28.41
# Second innings
# 32(120) 4s:3,6s:0,SR:26.67
#
#
# How many did Rishabh Pant score?
# **************
# First innings
# 36(67) 4s:4,6s:0,SR:53.73
# Second innings
# 64(80) 4s:6,6s:3,SR:80.0
#
#
# How many did Hanuma Vihari score?
# **************
# First innings
# 4(38) 4s:0,6s:0,SR:10.53
# Yet to bat/not batted
#
#
# How many did Ajinkya Rahane score?
# **************
# First innings
# 22(70) 4s:1,6s:1,SR:31.43
# Second innings
# 4(18) 4s:0,6s:0,SR:22.22
#
#
# How many did Shubman Gill score?
# **************
# First innings
# 50(102) 4s:8,6s:0,SR:49.02
# Second innings
# 31(64) 4s:4,6s:0,SR:48.44
#
#
# How many did Rohit Sharma score?
# **************
# First innings
# 26(77) 4s:3,6s:1,SR:33.77
# Second innings
# 52(98) 4s:5,6s:1,SR:53.06
#
#
# Bowling figures of Pat Cummins?
# **************
# First innings
# 21.4-29-4
# Second innings
# 14.1-38-1
#
#
# Bowling figures of Cameron Green?
# **************
# First innings
# 5.0-11-0
# Second innings
# 3.0-13-0
#
#
# Bowling figures of Mitchell Starc?
# **************
# First innings
# 19.1-61-1
# Second innings
# 9.4-44-0
#
#
# Bowling figures of Nathan Lyon?
# **************
# First innings
# 31.0-87-0
# Second innings
# 21.0-63-1
#
#
# Bowling figures of Josh Hazlewood?
# **************
# First innings
# 21.0-43-2
# Second innings
# 13.0-20-1
#
#
# Bowling figures of Marnus Labuschagne?
# **************
# First innings
# 3.0-11-0
# Second innings
# 2.0-9-0
#
#
# Bowling figures of Jasprit Bumrah?
# **************
# First innings
# 25.4-66-2
# Second innings
# 21.0-68-1
#
#
# Bowling figures of Ravindra Jadeja?
# **************
# First innings
# 18.0-62-4
# Havent bowled in second innings yet
#
#
# Bowling figures of Navdeep Saini?
# **************
# First innings
# 13.0-65-2
# Second innings
# 16.2-54-2
#
#
# Bowling figures of Mohammed Siraj?
# **************
# First innings
# 25.0-67-1
# Second innings
# 25.1-90-1
#
#
# Bowling figures of Ravichandran Ashwin?
# **************
# First innings
# 24.0-74-0
# Second innings
# 25.0-95-2

# %%
def util_summary_batsman(summary,innings = 1):
    if innings == 1:
        ans = "---First Innings---\n"
    else:
        ans = "---Second Innings---\n"
    lis = []
    for idx,player in enumerate(summary['innings']):
        lis.append(player)
    lis = reversed(lis)
    for player in lis:
        player_ = summary['innings'][player]
        s = "{} {}({})".format(player,player_['score'],player_['balls'])
        ans+=s
        ans+='\n'
    ans+='\n'
    return ans

def get_batting_summary(scores):
    """scores has innings key, result is input for util summary batsman"""
    result = dict()
    temp = dict()
    for key in scores:
        temp[key] = scores[key]
        result['innings'] = temp
    return result

# %%
def get_batting_summary_(data,team):
    scores = {}
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    result = dict()
    if team == 1:
        temp = dict()
        for key in reversed(scores[1][0]):
            temp[key] = scores[1][0][key]
        result['first_innings'] = temp
        if data_len >=3:
            temp = dict()
            for key in reversed(scores[3][0]):
                temp[key] = scores[3][0][key]
            result['second_innings'] = scores[3][0]
    else:
        temp = dict()
        if 2 in scores:
	        for key in reversed(scores[2][0]):
	            temp[key] = scores[2][0][key]
	        result['first_innings'] = temp
	#         result['first_innings'] = scores[2][0]
	        if data_len >3:
	            temp = dict()
	            for key in reversed(scores[4][0]):
	                temp[key] = scores[4][0][key]
	            result['second_innings'] = temp
    return result

# %%
get_batting_summary_(data,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-081bc1d05b1e> in <module>
# ----> 1 get_batting_summary_(data,1)
#
# <ipython-input-36-ac5a6706e083> in get_batting_summary_(data, team)
#       7     if team == 1:
#       8         temp = dict()
# ----> 9         for key in reversed(scores[1][0]):
#      10             temp[key] = scores[1][0][key]
#      11         result['first_innings'] = temp
#
# TypeError: 'dict' object is not reversible

# %%
scores ={}
data_len = len(data)
for j,i in enumerate(range(data_len-1,-1,-1)):
    scores[j+1] = get_scorecard(data[i])

# %%
# get_most_wickets(data)
t = {'australia': {'1': {}, '2': {}}, 'india': {'1': {}, '2': {}}}
for key in reversed(t):
    print(key)
# Out:
# india
# australia

# %%
def get_most_wickets(data):
    scores = {}
    result = dict()
    
    data_len = len(data)
    teams = get_playing_eleven(data)
    
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    for key in scores:
        for player in scores[key][1]:
            if player not in result:
                result[player] = []
            player_ = scores[key][1][player]
            s = int(player_['wickets'])
            result[player].append(s)
    result_final = {k.lower().strip():{'1':{},'2':{}} for k in teams}
    
    print(result_final)
    for player in result:
        team =get_player_team(player)
        result_final[team]['1'][player] = result[player][0] 
        if len(result[player]) > 1:
            result_final[team]['2'][player] = result[player][1] 
    res = dict()
    for team in result_final:
        res[team] = get_max(result_final[team])
    return res

# %%
x ={'1':10,'2':100,'3':-1}
sorted_x = sorted(x.items(), key=lambda kv: kv[1],reverse=True)
sorted_x
# Out:
# [('2', 100), ('1', 10), ('3', -1)]

# %%
def get_max(scores):
    first_in = scores['1']
    sorted_first = sorted(first_in.items(), key=lambda kv: kv[1],reverse=True)
    second_in = scores['2']
    sorted_second = sorted(second_in.items(), key=lambda kv: kv[1],reverse=True)
    
    return sorted_first[0],sorted_second[0]

def get_most_runs(data):
    ##issue when player doesnt bat in first but does in second, need to be tackled
    scores = {}
    result = dict()
    
    data_len = len(data)
    teams = get_playing_eleven(data)
    
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    for key in scores:
        for player in scores[key][0]:
            if player not in result:
                result[player] = []
            player_ = scores[key][0][player]
            s = int(player_['score'])
            result[player].append(s)
    
    scores_ = {k:{'1':{},'2':{}} for k in teams}
    for player in result:
        team = get_player_team(player)
        scores_[team]['1'][player] =result[player][0]
        if len(result[player]) > 1:
            scores_[team]['2'][player] =result[player][1]
    result_final = {k:{'1':{},'2':{}}for k in teams}
#     print(scores_)
    
    for team in scores_:
        result_final[team] = get_max(scores_[team])
    return result_final


def get_player_team(pname):
    teams = get_playing_eleven(data)
    for team in teams:
        for player in teams[team].split(','):
            if pname.lower() in player.lower():
                return team
    return None


def get_fow(data):
    scores = {}
    result = dict()
    
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    for key in scores:
        for player in scores[key][0]:
            if player not in result:
                result[player] = []
            player_ = scores[key][0][player]
            temp = player_['fow']
            result[player].append(temp)
    return result
    
def get_boundaries_playerwise(data):
    scores = {}
    result = dict()
    
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    for key in scores:
        for player in scores[key][0]:
            if player not in result:
                result[player] = []
            player_ = scores[key][0][player]
            temp = {'4':'','6':''}
            temp['4'] = player_['4s']
            temp['6'] = player_['6s']
#             s = "At {} -- {}".format(player_['fow'],player_['wk_comm'])
            result[player].append(temp)
    return result
    
def get_how_out(data,team_1):
    scores = {}
    result = dict()
    
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    for key in scores:
        for player in scores[key][0]:
            if player not in result:
                result[player] = []
            player_ = scores[key][0][player]
            if player_['fow'] == '':
                s = "Is {} ".format("not out")
                result[player].append(s)
                continue
            s = "At {} -- {}".format(player_['fow'],player_['wk_comm'])
            result[player].append(s)
    return result
    
    
def get_wickets_playerwise(data):
    scores = {}
    result = dict()
    
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    for key in scores:
        for player in scores[key][1]:
            if player not in result:
                result[player] = []
            player_ = scores[key][1][player]
            s = "{}-{}-{}".format(player_['overs'], player_['runs_conceeded'],player_['wickets'])
            result[player].append(s)
    return result

def get_score_playerwise(data):
    scores = {}
    result = dict()
    
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    for key in scores:
        for player in scores[key][0]:
            if player not in result:
                result[player] = []
            player_ = scores[key][0][player]
            s = "{} ({}) 4s:{},6s:{},SR:{}".format(player_['score'],player_['balls'],
                                            player_['4s'],player_['6s'],player_['sr'])
            result[player].append(s)
    return result
    
def get_dropped(data,team_1):
    util = 'DROPPED'
    if team_1:
        idx_list = [len(data) -1, len(data) - 3]
    else:
        idx_list = [len(data) -2, len(data)-4]
    comm = ["First Innings...."]
    flag = True
    innings_list = [data[idx_list[0]],data[idx_list[1]]]
    for inning in innings_list:
        try:
            for ball in reversed(inning['list']):
                if util in ball['Commentary']:
                    comm.append(ball["Over"]+ " "+ ball['Batsman_Name']+ ", "+ball['Commentary'])
        except IndexError:
            print("index error")
        if flag:
            comm.append("Second innings...")
            flag = False
    return comm

    

def get_bowling_summary(data,team):
    scores = {}
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    result = dict()
    if team == 1:
        result['first_innings'] = scores[2][1]
        if data_len >=4:
            result['second_innings'] = scores[4][1]
        else:
            result['second_innings'] = None
    else:
        result['first_innings'] = scores[1][1]
        if data_len >= 3:
            result['second_innings'] = scores[3][1]
        else:
            result['second_innings'] = None
    return result

def get_batting_summary(data,team):
    scores = {}
    data_len = len(data)
    for j,i in enumerate(range(data_len-1,-1,-1)):
        scores[j+1] = get_scorecard(data[i])
    result = dict()
    if team == 1:
#         scores[1][0] = reversed(scores[1][0])
        result['first_innings'] = scores[1][0]
        print(reversed(result['first_innings']))
        if data_len >=3:
            result['second_innings'] = scores[3][0]
    else:
        result['first_innings'] = scores[2][0]
        if data_len >3:
            result['second_innings'] = scores[4][0]
    return result
        

def get_all_players(data):
    teams_dict = get_playing_eleven(data)
    all_players = []
    
    for team in teams_dict:
        all_players += teams_dict[team].split(',')
    return all_players

def get_mom(data):
    util = "man of the match"
    util2 = 'player of the match'
    mom_string = ""
    for ball in data[0]['list']:
        if util in ball["Commentary"].lower():
            idx = ball['Commentary'].lower().find('match')
            mom_string = ball['Commentary'][:idx]
            break
        if util2 in ball['Commentary'].lower():
            idx = ball['Commentary'].lower().find('match')
            mom_string = ball['Commentary'][:idx]
            break
    doc = nlp(mom_string)
    persons = []
    
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            persons.append(ent.text)
    all_players = get_all_players(data)
#     print(persons)
    for person in persons:
        for player in all_players:
            if person in player:
                return player.strip()
            
    return None


def get_game_result(scorecard,data):
    if get_eom_status(scorecard):
        #do it from scores
        return "team a or team b"
    else:
        return "game yet to be finished"
    
def get_eom_status(scorecard):
    util1="CLOSE OF PLAY"
    util2 = "MATCH NOTES"
    eom = "end of match"
    lines = scorecard.split('\n')
    for idx,line in enumerate(lines):
        if util1 in line:
            idx1 = idx
        if util2 in line:
            idx2 = idx
#     print()
    if eom in lines[idx1+1:idx2][-1]:
        return True
    else:
        return False

def get_team_names(scorecard):
    util = "1ST INNINGS"
    flag = False
    team1,team2 = '',''
    for line in scorecard.split('\n'):
        if util in line:
            if not flag:
                team1 = line.split(util)[0].title()
                flag = True
            else:
                team2 = line.split(util)[0].title()
    return team1,team2


def get_playing_eleven(data):
    util = "(Playing XI) "
    teams = []
    for ball in data[len(data)-1]['list']:
        comm = ball['Commentary']
        if util in comm:
            teams.append(comm.split('-'))
    all_players = teams[0][1].split(',') + teams[1][1].split(',')
    team1 = teams[0][0][:teams[0][0].find('(')]
    team2 = teams[1][0][:teams[1][0].find('(')]
    teams_ = dict()
    teams_[team1.lower().strip()] = teams[0][1].strip()
    teams_[team2.lower().strip()] = teams[1][1].strip()
    return teams_            

def get_score(batsman,data):
    result_dict = dict(i1 = 0,i2 = 0)
    first_bat,first_bowl = get_scorecard(data[len(data)-1])
    for player in first_bat:
        if batsman.lower() in player.lower():
            player_dict = first_bat[player]
#             print(first_bat[player])
            s = "{}({}) 4s:{},6s:{},SR:{}".format(player_dict['score'], player_dict['balls'],
                                        player_dict['4s'],player_dict['6s'],player_dict['sr'])
            return s

def get_wickets_comm(data,team_1):
    if team_1:
        idx_list = [len(data) -1, len(data) - 3]
    else:
        idx_list = [len(data) -2, len(data)-4]
    comm = ["First Innings...."]
    flag = True
    innings_list = [data[idx_list[0]],data[idx_list[1]]]    
    
    for inning in innings_list:
        try:
            for ball in reversed(inning['list']):
                if "Iswicket" in ball and ball['Iswicket']:
                    comm.append(ball['Over']+ " "+ball['Batsman_Name']+" "+ball["Commentary"])
#                 if ball['Iswicket']:
#                     comm.append(ball["Over"]+' '+ball['Commentary'])
        except IndexError:
            print("index error")
        if flag:
            comm.append("Second innings...")
            flag = False
    return comm

def get_fours_comm(data, team_1):
    if team_1:
        idx_list = [len(data) -1, len(data) - 3]
    else:
        idx_list = [len(data) -2, len(data)-4]
    comm = ["First Innings...."]
    flag = True
    innings_list = [data[idx_list[0]],data[idx_list[1]]]
    for inning in innings_list:
        try:
            for ball in reversed(inning['list']):
                if ball['Batsman_Runs'] == '4':
                    comm.append(ball["Over"]+' '+ball['Commentary'])
        except IndexError:
            print("index error")
        if flag:
            comm.append("Second innings...")
            flag = False
    return comm

def get_six_comm(data, team_1):
    if team_1:
        idx_list = [len(data) -1, len(data) - 3]
    else:
        idx_list = [len(data) -2, len(data)-4]
    comm = ["First Innings...."]
    flag = True
    innings_list = [data[idx_list[0]],data[idx_list[1]]]
    for inning in innings_list:
        try:
            for ball in reversed(inning['list']):
                if ball['Batsman_Runs'] == '6':
                    comm.append(ball["Over"]+" "+ball['Batsman_Name']+" "+ball['Commentary'])
        except IndexError:
            print("index error")
        if flag:
            comm.append("Second innings...")
            flag = False
    return comm


def get_captain(data,team1,team2):
	cap = "(C"
	cap3 = "(WK/C)"
	pl = "(Playing XI"
	# team1,team2  ='',''
	teams = []
	teams.append(get_playing_eleven(data)[team1.lower()])
	teams.append(get_playing_eleven(data)[team2.lower()]) 
	cap1,cap2 = '',''
	for i in range(2):
		for player in teams[i].split(','):
			if pl in player:
				if i == 0:
					team1 = player.split(pl)[0].strip()
				else:
					team2 = player.split(pl)[0].strip()
			f1 = cap in player

			f3 = cap3 in player
			if f1 or f3:
				if i == 0:
					cap1 = player.strip()
				else:
					cap2 = player.strip()
	res = dict()
	res[team1.strip().lower()] = cap1
	res[team2.strip().lower()] = cap2
	return res


def get_scorecard(commentary):
    ##to do -- add maidens and no balls or wides
    ## run outs being added to bowler bowled fix needed
    batsman_scores = dict()
    bowler_stats = dict()
    wide = "WIDE"
    nobe = "NO BALL"
    for ball in commentary['list']:
        comm = ball["Commentary"]
        if ball['Isball']:
            bowler = ball["Bowler_Name"]
            batter = ball['Batsman_Name']
            score = int(ball['Batsman_Runs'])
            if bowler not in bowler_stats:
                bowler_stats[bowler] ={'overs':0,'runs_conceeded':0, "wickets":0,
                                       "wides":0,"no_ball":0} 
                
            if batter not in batsman_scores:
                    batsman_scores[batter] = {'score':0,'balls':0,'4s':0,
                                              '6s':0,'sr':0,'fow':'','wk_comm':''}
            if score == 4:
                batsman_scores[batter]['4s']+=1
            if score == 6:
                batsman_scores[batter]['6s'] +=1
            batsman_scores[batter]['score'] += int(score)
            batsman_scores[batter]['balls'] += 1
            bowler_stats[bowler]['runs_conceeded'] += int(ball["Bowler_Conceded_Runs"])
            f1 = wide in comm
            f2 = nobe in comm
            if f1:
                bowler_stats[bowler]['wides']+=1
            elif f2:
                bowler_stats[bowler]['no_ball']+=1
            else:
                bowler_stats[bowler]['overs'] += 1
            if "Iswicket" in ball and ball['Iswicket']:
                batsman_scores[batter]['fow'] = ball['Over']
                batsman_scores[batter]['wk_comm'] = comm
                if ball['Dismissal_Type'] == 'run out':
                    continue
                bowler_stats[bowler]['wickets'] += 1
                
    for bowler in bowler_stats:
        overs_ = bowler_stats[bowler]['overs']//6
        decimal = bowler_stats[bowler]['overs'] % 6
        overs = str(overs_)+'.'+str(decimal)
        bowler_stats[bowler]['overs'] = overs
        ##fix extras
    for batsman in batsman_scores:
        sr = int(batsman_scores[batsman]['score'])/int(batsman_scores[batsman]['balls']) * (100)
        batsman_scores[batsman]['sr'] = round(sr,2)
    return batsman_scores, bowler_stats

def get_day_summary(data):
#     count = len(data)
#     get_daywise
    for ball in data[0]['list']:
        if ball['Isball']:
            break
        prev_ball = ball
    return prev_ball['Commentary']

def get_scores(data):
    ##extras not considered in scores
    current = len(data)
    result_scores = []
    result_wickets = []
    result_dict = dict()
    for inning in data:
        card = get_scorecard(inning)
        score,wickets = 0,0
        for player in card[0]:
            score +=card[0][player]['score']
        for player in card[1]:
            wickets+= card[1][player]['wickets']
        result_scores.append(score)
        result_wickets.append(len(card[0]) - 1)
    assert len(result_scores) == len(result_wickets)
    k = 0 
    for idx in range(len(data),0,-1):
        temp = 'i'+ str(idx)
#         if temp not in 
        result_dict[temp] = str(result_scores[k]) + '/'+ str(result_wickets[k])
        k+=1
    
    return result_dict

def get_daywise(data):
    from collections import Counter
    all_days = []
    daywise = dict(day1 = list(), day2 = list(), day3 = list(), day4 = list(), day5 = list())
    for ball in data[-1]['list']:
        if 'Timestamp' in ball:
            time = ball['Timestamp']
            day1 = int(time.split('T')[0][-2:])
            if day1 > 26:
                print("might face issue, TODO part, will deal with it")
            break
    day2,day3,day4,day5 = day1+1, day1+2,day1+3,day1+4
    print(day1,day2,day3,day4,day5)
    for j,i in enumerate(range(len(data)-1,0,-1)):
        for ball in reversed(data[i]['list']):
            time = ball['Timestamp']
            day = int(time.split('T')[0][-2:])
            all_days.append(day)
            if day == day1:
                daywise['day1'].append(ball)
            elif day == day2:
                daywise['day2'].append(ball)
            elif day == day3:
                daywise['day3'].append(ball)
            elif day == day4:
                daywise['day4'].append(ball)
            elif day == day5:
                daywise['day5'].append(ball)
    print(Counter(all_days))
    
    return daywise


def get_teams(scorecard):
    util = "1ST INNINGS"
    flag = False
    team1,team2 = '',''
    for line in scorecard.split('\n'):
        if util in line:
#             print(line)
            if not flag:
                team1 = line.split(util)[0].title()
                flag = True
            else:
                team2 = line.split(util)[0].title()
    return team1,team2

def get_toss(scorecard):
    for line in scorecard.split('\n'):
        if "toss" in line.lower():
            return line.split('\t')[-1].strip()

        
def get_match_status(data,scorecard):
    pass
#     print(line)

# %%
##get list day wise, given data

def generate_qa(question,answer):
    ##todo
    #returns question and answer
    pass
    
qa_list = []

# qa.append(generate_qa(who_won_the_toss, ))
# qa.append(generate_qa(playing eleven of both sides, ))# done
# qa.append(generate_qa(captain of team1, ))
# qa.append(generate_qa(captain of team2, ))
# qa.append(generate_qa(wicket keeper of team1, ))
# qa.append(generate_qa(wicket keeper of team2, ))
# qa.append(generate_qa(session wise break down of day or whole match, ))
#summary of the day
#team wise innings summary
#list of commentary fours innings wise
#list of comm wickets
#list of drop catches
#how many runs each player scored each innings
#how many sixes,fours did they hit..
#wickets, wides, nobes of bowlers
#fall of wicket.
#most runs, least runs, most wickets.
#sixes fours over all team
#extras for overall team


##day wise questions
#end of the day stats?
#most runs scored today?
#most wickets today?
#summary of day?
#score status today? trailing or not
#which day today?
#how many days left?

# %%
scorecard = """

AUSTRALIA 1ST INNINGS
BATSMEN	 	R	B	M	4s	6s	SR	 
Will Pucovski 	lbw b Saini	62	110	150	4	0	56.36	
David Warner 	c Pujara b Mohammed Siraj	5	8	17	0	0	62.50	
Marnus Labuschagne 	c Rahane b Jadeja	91	196	281	11	0	46.43	
Steven Smith 	run out (Jadeja)	131	226	303	16	0	57.96	
Matthew Wade 	c Bumrah b Jadeja	13	16	25	2	0	81.25	
Cameron Green 	lbw b Bumrah	0	21	31	0	0	0.00	
Tim Paine (c)†	 b Bumrah	1	10	18	0	0	10.00	
Pat Cummins 	 b Jadeja	0	13	28	0	0	0.00	
Mitchell Starc 	c Shubman Gill b Saini	24	30	32	2	1	80.00	
Nathan Lyon 	lbw b Jadeja	0	3	5	0	0	0.00	
Josh Hazlewood 	not out	1	6	16	0	0	16.67	
Extras	(b 4, nb 5, w 1)	10	
TOTAL	(105.4 Ov, RR: 3.20)	338	
Fall of wickets: 1-6 (David Warner, 3.3 ov), 2-106 (Will Pucovski, 34.2 ov), 3-206 (Marnus Labuschagne, 70.5 ov), 4-232 (Matthew Wade, 76.5 ov), 5-249 (Cameron Green, 84.5 ov), 6-255 (Tim Paine, 88.5 ov), 7-278 (Pat Cummins, 94.4 ov), 8-310 (Mitchell Starc, 101.5 ov), 9-315 (Nathan Lyon, 102.4 ov), 10-338 (Steven Smith, 105.4 ov)
BOWLING	O	M	R	W	ECON	WD	NB	 
Jasprit Bumrah	25.4	7	66	2	2.57	0	0	
Mohammed Siraj	25	4	67	1	2.68	1	0	
Ravichandran Ashwin	24	1	74	0	3.08	0	0	
Navdeep Saini	13	0	65	2	5.00	0	3	
Ravindra Jadeja	18	3	62	4	3.44	0	2	
INDIA 1ST INNINGS
BATSMEN	 	R	B	M	4s	6s	SR	 
Rohit Sharma 	c & b Hazlewood	26	77	111	3	1	33.77	
Shubman Gill 	c Green b Cummins	50	101	134	8	0	49.50	
Cheteshwar Pujara 	c †Paine b Cummins	50	176	278	5	0	28.41	
Ajinkya Rahane (c)	 b Cummins	22	70	95	1	1	31.43	
Hanuma Vihari 	run out (Hazlewood)	4	38	56	0	0	10.53	
Rishabh Pant †	c Warner b Hazlewood	36	67	101	4	0	53.73	
Ravindra Jadeja 	not out	28	37	75	5	0	75.68	
Ravichandran Ashwin 	run out (Cummins/Labuschagne)	10	15	23	2	0	66.67	
Navdeep Saini 	c Wade b Starc	3	13	11	0	0	23.08	
Jasprit Bumrah 	run out (Labuschagne)	0	2	9	0	0	0.00	
Mohammed Siraj 	c †Paine b Cummins	6	10	28	1	0	60.00	
Extras	(lb 2, nb 2, w 5)	9	
TOTAL	(100.4 Ov, RR: 2.43)	244	
Fall of wickets: 1-70 (Rohit Sharma, 26.6 ov), 2-85 (Shubman Gill, 32.1 ov), 3-117 (Ajinkya Rahane, 54.4 ov), 4-142 (Hanuma Vihari, 67.2 ov), 5-195 (Rishabh Pant, 87.4 ov), 6-195 (Cheteshwar Pujara, 88.2 ov), 7-206 (Ravichandran Ashwin, 92.2 ov), 8-210 (Navdeep Saini, 94.5 ov), 9-216 (Jasprit Bumrah, 96.3 ov), 10-244 (Mohammed Siraj, 100.4 ov)
BOWLING	O	M	R	W	ECON	WD	NB	 
Mitchell Starc	19	7	61	1	3.21	0	2	
Josh Hazlewood	21	10	43	2	2.05	1	0	
Pat Cummins	21.4	10	29	4	1.34	0	0	
Nathan Lyon	31	8	87	0	2.81	0	0	
Marnus Labuschagne	3	0	11	0	3.67	0	0	
Cameron Green	5	2	11	0	2.20	0	0	
AUSTRALIA 2ND INNINGS
BATSMEN	 	R	B	M	4s	6s	SR	 
David Warner 	lbw b Ashwin	13	29	50	1	0	44.83	
Will Pucovski 	c sub (WP Saha) b Mohammed Siraj	10	16	30	2	0	62.50	
Marnus Labuschagne 	c sub (WP Saha) b Saini	73	118	179	9	0	61.86	
Steven Smith 	lbw b Ashwin	81	167	261	8	1	48.50	
Matthew Wade 	c sub (WP Saha) b Saini	4	11	16	1	0	36.36	
Cameron Green 	c sub (WP Saha) b Bumrah	84	132	183	8	4	63.64	
Tim Paine (c)†	not out	39	52	99	6	0	75.00	
Extras	(b 1, lb 4, nb 3)	8	
TOTAL	(87 Ov, RR: 3.58)	312/6d	
Did not bat: Pat Cummins, Mitchell Starc, Nathan Lyon, Josh Hazlewood 
Fall of wickets: 1-16 (Will Pucovski, 5.5 ov), 2-35 (David Warner, 9.2 ov), 3-138 (Marnus Labuschagne, 46.1 ov), 4-148 (Matthew Wade, 48.6 ov), 5-208 (Steven Smith, 67.4 ov), 6-312 (Cameron Green, 86.6 ov)
BOWLING	O	M	R	W	ECON	WD	NB	 
Jasprit Bumrah	21	4	68	1	3.24	0	0	
Mohammed Siraj	25	5	90	1	3.60	0	1	
Navdeep Saini	16	2	54	2	3.38	0	2	
Ravichandran Ashwin	25	1	95	2	3.80	0	0	
INDIA 2ND INNINGS (TARGET: 407 RUNS)
BATSMEN	 	R	B	M	4s	6s	SR	 
Rohit Sharma 	c Starc b Cummins	52	98	136	5	1	53.06	
Shubman Gill 	c †Paine b Hazlewood	31	64	103	4	0	48.44	
Cheteshwar Pujara 	 b Hazlewood	77	205	205	12	0	37.56	
Ajinkya Rahane (c)	c Wade b Lyon	4	18	18	0	0	22.22	
Rishabh Pant †	c Cummins b Lyon	97	118	118	12	3	82.20	
Hanuma Vihari 	not out	23	161	161	4	0	14.29	
Ravichandran Ashwin 	not out	39	128	128	7	0	30.47	
Extras	(lb 3, nb 6, w 2)	11	
TOTAL	(131 Ov, RR: 2.55)	334/5	
Did not bat: Ravindra Jadeja, Navdeep Saini, Jasprit Bumrah, Mohammed Siraj 
Fall of wickets: 1-71 (Shubman Gill, 22.1 ov), 2-92 (Rohit Sharma, 30.2 ov), 3-102 (Ajinkya Rahane, 35.4 ov), 4-250 (Rishabh Pant, 79.1 ov), 5-272 (Cheteshwar Pujara, 88.2 ov)
BOWLING	O	M	R	W	ECON	WD	NB	 
Mitchell Starc	22	6	66	0	3.00	0	2	
Josh Hazlewood	26	12	39	2	1.50	0	1	
Pat Cummins	26	6	72	1	2.77	0	2	
Nathan Lyon	46	17	114	2	2.48	0	0	
Cameron Green	7	0	31	0	4.43	2	0	
Marnus Labuschagne	4	2	9	0	2.25	0	1	
MATCH DETAILS
Sydney Cricket Ground
Toss	Australia, elected to bat first
Series	
India tour of Australia
ICC World Test Championship
Season	2020/21
Player Of The Match	
Steven Smith
Steven Smith
Series result	4-match series level 1-1
Match number	TEST No. 2402
Over 67.4: Review by India (Bowling), Umpire - PR Reiffel, Batsman - SPD Smith (Upheld)
Australia: 250 runs in 77.6 overs (471 balls), Extras 4
6th Wicket: 50 runs in 67 balls (C Green 21, TD Paine 29, Ex 0)
Drinks: Australia - 258/5 in 79.0 overs (C Green 44, TD Paine 29)
New ball taken after 82nd over
C Green: 50 off 116 balls (7 x 4)
Australia: 300 runs in 85.6 overs (519 balls), Extras 8
6th Wicket: 100 runs in 115 balls (C Green 61, TD Paine 39, Ex 4)
Tea: Australia - 312/6 in 87.0 overs (TD Paine 39)
Over 86.6: Review by Australia (Batting), Umpire - P Wilson, Batsman - C Green (Struck down)
India 2nd innings
Over 7.2: Review by India (Batting), Umpire - PR Reiffel, Batsman - RG Sharma (Upheld)
Over 7.4: Review by Australia (Bowling), Umpire - PR Reiffel, Batsman - Shubman Gill (Struck down)
Drinks: India - 46/0 in 17.0 overs (RG Sharma 22, Shubman Gill 23)
India: 50 runs in 18.6 overs (114 balls), Extras 1
1st Wicket: 50 runs in 114 balls (RG Sharma 22, Shubman Gill 30, Ex 1)
Over 22.1: Review by India (Batting), Umpire - P Wilson, Batsman - Shubman Gill (Struck down)
Over 22.4: Review by India (Batting), Umpire - P Wilson, Batsman - CA Pujara (Upheld)
RG Sharma: 50 off 95 balls (5 x 4, 1 x 6)
End Of Day: India - 98/2 in 34.0 overs (CA Pujara 9, AM Rahane 4)
Day 5
India: 100 runs in 35.2 overs (213 balls), Extras 2
India: 150 runs in 52.3 overs (318 balls), Extras 4
4th Wicket: 50 runs in 103 balls (CA Pujara 13, RR Pant 35, Ex 2)
Drinks: India - 152/3 in 53.0 overs (CA Pujara 26, RR Pant 35)
RR Pant: 50 off 64 balls (4 x 4, 3 x 6)
India: 200 runs in 67.6 overs (412 balls), Extras 5
4th Wicket: 100 runs in 197 balls (CA Pujara 24, RR Pant 73, Ex 3)
Lunch: India - 206/3 in 70.0 overs (CA Pujara 41, RR Pant 73)
CA Pujara: 50 off 170 balls (7 x 4)
India: 250 runs in 78.1 overs (473 balls), Extras 8
New ball taken after 80th over
Drinks: India - 262/4 in 84.0 overs (CA Pujara 70, GH Vihari 0)
Over 91.4: Review by Australia (Bowling), Umpire - PR Reiffel, Batsman - R Ashwin (Struck down)
Tea: India - 280/5 in 96.0 overs (GH Vihari 4, R Ashwin 7)
Over 96.1: Review by India (Batting), Umpire - P Wilson, Batsman - R Ashwin (Upheld)
India: 300 runs in 114.6 overs (694 balls), Extras 8
Drinks: India - 305/5 in 117.0 overs (GH Vihari 7, R Ashwin 28)
6th Wicket: 50 runs in 246 balls (GH Vihari 16, R Ashwin 33, Ex 3)
"""

# %%
util = "DROP"
doc = nlp("Kyle Jamieson has been named as the player of the match")
# doc = 
proper_nouns = []
ents_list = []



# for ball in data[1]['list']:
#     comm = ball['Commentary']
#     if util in comm:
#         doc = nlp(comm)
        
#         for token in doc:
#             if token.pos_ == "PROPN":
#                 proper_nouns.append(token.text)
#         for ent in doc.ents:
#             if ent.label_ == "PERSON":
#                 ents_list.append(ent.text)
# all_players = []
